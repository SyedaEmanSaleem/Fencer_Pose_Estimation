# %% [markdown]
# ### YOLOv8 Pose Model Initialization

# %%
from ultralytics import YOLO
model = YOLO("yolov8n-pose.pt")

# %% [markdown]
# ### YOLOv8 Pose Model Training

# %%
# !yolo pose train \
  model=yolov8n-pose.pt \
  data="/content/drive/My Drive/Fencer Pose.v4i.yolov8/data.yaml" \
  epochs=150 \
  name="train2_tuned" \
  lr0=0.0005 \
  weight_decay=0.0001 \
  warmup_epochs=3 \
  patience=30 \
  amp=False
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# ### YOLOv8 Pose Model Evaluation

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/pose/train2_tuned6/weights/best.pt')
model.val()
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-pose summary (fused): 81 layers, 3,209,462 parameters, 0 gradients, 8.8 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 32.6±3.5 MB/s, size: 38.8 KB)
# val: Scanning /content/drive/My Drive/Fencer Pose.v4i.yolov8/valid/labels.cache... 92 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 92/92 165.8Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 0.9it/s 6.9s
#                    all         92        434      0.903      0.868      0.892      0.638      0.534      0.489       0.48      0.326
#                 fencer         91        181      0.977          1      0.987      0.823      0.961      0.983       0.97      0.721
#                  saber         85        157      0.822      0.648      0.712      0.308      0.642      0.484      0.468      0.255
# ...

# %% [markdown]
# ### Load Trained YOLOv8 Pose Model for Inference

# %%
infr_model=YOLO('/content/drive/My Drive/train2_tuned6/weights/best.pt')

# %% [markdown]
# ### YOLOv8 Pose Model Inference on Test Images

# %%
results = infr_model("/content/drive/My Drive/Fencer Pose.v4i.yolov8/test/images",conf=0.6)
results[36].show()
# Out:
# image 1/47 /content/drive/My Drive/Fencer Pose.v4i.yolov8/test/images/0_104_jpg.rf.458b586c8eb98ce5bd97555b627b9d5d.jpg: 640x640 2 fencers, 2 scoreboxs, 10.9ms
# image 2/47 /content/drive/My Drive/Fencer Pose.v4i.yolov8/test/images/0_76_jpg.rf.c09434ad16cffe8c89de01a80e288b83.jpg: 640x640 2 fencers, 2 scoreboxs, 8.2ms
# image 3/47 /content/drive/My Drive/Fencer Pose.v4i.yolov8/test/images/100_12_jpg.rf.ba7b2274d70bc6e9ad6dad0e99c6bb8a.jpg: 640x640 2 fencers, 1 saber, 1 scorebox, 8.2ms
# image 4/47 /content/drive/My Drive/Fencer Pose.v4i.yolov8/test/images/100_152_jpg.rf.e6b8a3ad862f55433cc65fa6b0105f3c.jpg: 640x640 2 fencers, 1 saber, 2 scoreboxs, 8.1ms
# image 5/47 /content/drive/My Drive/Fencer Pose.v4i.yolov8/test/images/100_180_jpg.rf.e97efe68d39bc57238b56e08aa23a40d.jpg: 640x640 2 fencers, 2 sabers, 2 scoreboxs, 8.2ms
# ...

# %% [markdown]
# ### Display Inference Result Image

# %%
from IPython.display import Image, display

display(Image("/content/drive/My Drive/train2_tuned6/results.png"))
